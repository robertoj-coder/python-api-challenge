# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
from api_keys import weather_api_key
from scipy.stats import linregress
import numpy as np
from citipy import citipy
import time

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
#url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial&q='

# %% [markdown]
# ## Generate Cities List

# %%
Coordinates = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000000, high=90.000000, size=1500)
lngs = np.random.uniform(low=-180.000000, high=180.000000, size=1500)
Coordinates = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for Coord in Coordinates:
    city = citipy.nearest_city(Coord[0], Coord[1]).city_name
    country = citipy.nearest_city(Coord[0], Coord[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm count


# set up lists to hold reponse info
# Loop through the list of cities and perform a request for data on each

# %%
# create a empty dataframe

cities_gen = pd.DataFrame({"City": cities, "Country": countries})

cities_gen["Lat"]= "" 
cities_gen["Lng"] = ""                          
cities_gen["Max Temp"] = "" 
cities_gen["Cloudiness"] = ""
cities_gen["Humidity"] = ""
cities_gen["Windspeed"] = ""
cities_gen["Date"] = ""

cities_gen.head()
# Out:
#                City Country Lat Lng Max Temp Cloudiness Humidity Windspeed  \
# 0            atuona      pf
# 1  illoqqortoormiut      gl
# 2         grindavik      is
# 3     mar del plata      ar
# 4         flin flon      ca
#
#   Date
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial&q='

# %%
#tracking the response number as my API key was temporary blocked due to the continual sufficient exceeding of the calls per minute limit 

index_count = 0
counter = 1

for index, row in cities_gen.iterrows(): 
    #Create the query url for the API call
    city_name = row['City']
    
    #print(f"Retrieving Results for Index {index} | {city_name}")
    query_url = url + city_name + "&APPID=" + weather_api_key
    
    #print(f"Processing Record {index + 1} | {City}")
   
    #API call
    
    response = requests.get(query_url).json()
    
    #Exception script in case the city is not found
    try: 
        #print(f'Weather Data for Record {number} of Set {the_set} 
        #Input data into the dataframe
        
        cities_gen.loc[index, 'Lat'] = response['coord']['lat']
        cities_gen.loc[index, 'Lng'] = response['coord']['lon']
        cities_gen.loc[index, 'Max Temp'] = response['main']['temp_max']
        cities_gen.loc[index, 'Cloudiness'] = response['clouds']['all']
     
        cities_gen.loc[index, 'Humidity'] = response['main']['humidity']
        cities_gen.loc[index, 'Windspeed'] = response['wind']['speed']
        cities_gen.loc[index, 'Date'] = response['dt']
        
        if index_count > 55:
            index_count = 0
            counter = counter + 1
    
        else:
            index_count = index_count + 1
            
        print(f"Processing {index_count} of Set {counter} : {city_name}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")
        time.sleep(10) 
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Processing 1 of Set 1 : atuona
# City not found. Skipping...
# Processing 2 of Set 1 : grindavik
# Processing 3 of Set 1 : mar del plata
# Processing 4 of Set 1 : flin flon
# Processing 5 of Set 1 : vilhena
# Processing 6 of Set 1 : rikitea
# Processing 7 of Set 1 : punta arenas
# Processing 8 of Set 1 : bridlington
# Processing 9 of Set 1 : kaitangata
# Processing 10 of Set 1 : tiarei
# Processing 11 of Set 1 : provideniya
# Processing 12 of Set 1 : palmer
# Processing 13 of Set 1 : albany
# Processing 14 of Set 1 : laguna
# Processing 15 of Set 1 : meadow lake
# Processing 16 of Set 1 : thompson
# Processing 17 of Set 1 : mataura
# Processing 18 of Set 1 : fortuna
# Processing 19 of Set 1 : portland
# Processing 20 of Set 1 : bluff
# Processing 21 of Set 1 : vaini
# Processing 22 of Set 1 : mareeba
# Processing 23 of Set 1 : butaritari
# Processing 24 of Set 1 : carnarvon
# Processing 25 of Set 1 : yellowknife
# Processing 26 of Set 1 : esperance
# Processing 27 of Set 1 : faanui
# Processing 28 of Set 1 : qaanaaq
# Processing 29 of Set 1 : zuwarah
# Processing 30 of Set 1 : port alfred
# Processing 31 of Set 1 : raga
# Processing 32 of Set 1 : saint george
# Processing 33 of Set 1 : kapaa
# Processing 34 of Set 1 : port elizabeth
# Processing 35 of Set 1 : ulagan
# Processing 36 of Set 1 : bambous virieux
# Processing 37 of Set 1 : new norfolk
# Processing 38 of Set 1 : bozoum
# Processing 39 of Set 1 : busselton
# Processing 40 of Set 1 : kodiak
# Processing 41 of Set 1 : spilamberto
# Processing 42 of Set 1 : jacobabad
# Processing 43 of Set 1 : dikson
# Processing 44 of Set 1 : olinda
# Processing 45 of Set 1 : santa maria
# City not found. Skipping...
# City not found. Skipping...
# Processing 46 of Set 1 : masuda
# Processing 47 of Set 1 : lavrentiya
# Processing 48 of Set 1 : mayumba
# Processing 49 of Set 1 : matara
# Processing 50 of Set 1 : torbay
# City not found. Skipping...
# Processing 51 of Set 1 : junin
# Processing 52 of Set 1 : along
# Processing 53 of Set 1 : puerto ayora
# Processing 54 of Set 1 : bowen
# Processing 55 of Set 1 : slave lake
# Processing 56 of Set 1 : sergeyevka
# Processing 0 of Set 2 : naryan-mar
# Processing 1 of Set 2 : altamira
# Processing 2 of Set 2 : hobart
# City not found. Skipping...
# City not found. Skipping...
# Processing 3 of Set 2 : chitrakonda
# Processing 4 of Set 2 : tuktoyaktuk
# Processing 5 of Set 2 : kavieng
# Processing 6 of Set 2 : souillac
# Processing 7 of Set 2 : vao
# Processing 8 of Set 2 : tasiilaq
# Processing 9 of Set 2 : ushuaia
# City not found. Skipping...
# Processing 10 of Set 2 : pangody
# Processing 11 of Set 2 : atouguia da baleia
# Processing 12 of Set 2 : mahebourg
# Processing 13 of Set 2 : opuwo
# Processing 14 of Set 2 : praia da vitoria
# Processing 15 of Set 2 : hermanus
# Processing 16 of Set 2 : praxedis guerrero
# Processing 17 of Set 2 : severo-kurilsk
# Processing 18 of Set 2 : huai thalaeng
# Processing 19 of Set 2 : ribeira grande
# Processing 20 of Set 2 : saint-philippe
# Processing 21 of Set 2 : lompoc
# Processing 22 of Set 2 : avera
# Processing 23 of Set 2 : ancud
# Processing 24 of Set 2 : fairbanks
# Processing 25 of Set 2 : namatanai
# Processing 26 of Set 2 : luau
# Processing 27 of Set 2 : maun
# Processing 28 of Set 2 : alekseyevsk
# Processing 29 of Set 2 : qaqortoq
# Processing 30 of Set 2 : marawi
# Processing 31 of Set 2 : limon
# Processing 32 of Set 2 : arraial do cabo
# Processing 33 of Set 2 : barrow
# Processing 34 of Set 2 : ostrovnoy
# Processing 35 of Set 2 : pevek
# Processing 36 of Set 2 : turukhansk
# Processing 37 of Set 2 : namibe
# Processing 38 of Set 2 : belaya gora
# Processing 39 of Set 2 : paamiut
# Processing 40 of Set 2 : alofi
# Processing 41 of Set 2 : teluk nibung
# Processing 42 of Set 2 : naze
# Processing 43 of Set 2 : jamestown
# Processing 44 of Set 2 : lucapa
# Processing 45 of Set 2 : wattegama
# Processing 46 of Set 2 : hithadhoo
# Processing 47 of Set 2 : byron bay
# Processing 48 of Set 2 : cape town
# Processing 49 of Set 2 : kavaratti
# Processing 50 of Set 2 : belmonte
# Processing 51 of Set 2 : clyde river
# Processing 52 of Set 2 : port hedland
# Processing 53 of Set 2 : san jose
# Processing 54 of Set 2 : norman wells
# Processing 55 of Set 2 : wadi maliz
# City not found. Skipping...
# Processing 56 of Set 2 : oranjemund
# Processing 0 of Set 3 : rio gallegos
# Processing 1 of Set 3 : lima
# Processing 2 of Set 3 : tiksi
# Processing 3 of Set 3 : ennis
# Processing 4 of Set 3 : tura
# Processing 5 of Set 3 : tautira
# Processing 6 of Set 3 : chuy
# Processing 7 of Set 3 : gombong
# Processing 8 of Set 3 : lazaro cardenas
# Processing 9 of Set 3 : khatanga
# Processing 10 of Set 3 : east london
# Processing 11 of Set 3 : pipri
# Processing 12 of Set 3 : margate
# Processing 13 of Set 3 : arman
# Processing 14 of Set 3 : hasaki
# Processing 15 of Set 3 : jumla
# Processing 16 of Set 3 : ereymentau
# Processing 17 of Set 3 : ahipara
# Processing 18 of Set 3 : chara
# Processing 19 of Set 3 : san antonio
# Processing 20 of Set 3 : aguimes
# Processing 21 of Set 3 : paramonga
# Processing 22 of Set 3 : yakeshi
# Processing 23 of Set 3 : kiama
# Processing 24 of Set 3 : udala
# Processing 25 of Set 3 : concepcion
# Processing 26 of Set 3 : lebu
# Processing 27 of Set 3 : bredasdorp
# Processing 28 of Set 3 : upernavik
# Processing 29 of Set 3 : kapit
# Processing 30 of Set 3 : banikoara
# Processing 31 of Set 3 : visnes
# Processing 32 of Set 3 : kindersley
# Processing 33 of Set 3 : saskylakh
# Processing 34 of Set 3 : evensk
# Processing 35 of Set 3 : maragogi
# Processing 36 of Set 3 : gushikawa
# Processing 37 of Set 3 : castro
# Processing 38 of Set 3 : torrelavega
# Processing 39 of Set 3 : nome
# Processing 40 of Set 3 : montana
# Processing 41 of Set 3 : jawhar
# Processing 42 of Set 3 : ahuimanu
# Processing 43 of Set 3 : talnakh
# City not found. Skipping...
# Processing 44 of Set 3 : taksimo
# Processing 45 of Set 3 : hervey bay
# Processing 46 of Set 3 : chokurdakh
# City not found. Skipping...
# Processing 47 of Set 3 : ponta do sol
# Processing 48 of Set 3 : puerto escondido
# Processing 49 of Set 3 : tuatapere
# Processing 50 of Set 3 : georgetown
# City not found. Skipping...
# Processing 51 of Set 3 : hilo
# Processing 52 of Set 3 : maiduguri
# Processing 53 of Set 3 : bondo
# Processing 54 of Set 3 : mamboma
# Processing 55 of Set 3 : araouane
# Processing 56 of Set 3 : kloulklubed
# Processing 0 of Set 4 : guerrero negro
# City not found. Skipping...
# Processing 1 of Set 4 : vila franca do campo
# Processing 2 of Set 4 : vanimo
# Processing 3 of Set 4 : constitucion
# Processing 4 of Set 4 : honningsvag
# Processing 5 of Set 4 : eureka
# Processing 6 of Set 4 : mokolo
# Processing 7 of Set 4 : ilulissat
# Processing 8 of Set 4 : victoria
# Processing 9 of Set 4 : jalu
# Processing 10 of Set 4 : avarua
# Processing 11 of Set 4 : falam
# Processing 12 of Set 4 : ballina
# Processing 13 of Set 4 : palapye
# Processing 14 of Set 4 : walvis bay
# Processing 15 of Set 4 : prince rupert
# Processing 16 of Set 4 : pochutla
# Processing 17 of Set 4 : sinnamary
# Processing 18 of Set 4 : campo largo
# Processing 19 of Set 4 : roald
# Processing 20 of Set 4 : quatre cocos
# Processing 21 of Set 4 : longyearbyen
# Processing 22 of Set 4 : yendi
# Processing 23 of Set 4 : petropavlovsk-kamchatskiy
# Processing 24 of Set 4 : kruisfontein
# Processing 25 of Set 4 : jibuti
# Processing 26 of Set 4 : aswan
# Processing 27 of Set 4 : mtwara
# Processing 28 of Set 4 : sisimiut
# Processing 29 of Set 4 : srednekolymsk
# Processing 30 of Set 4 : vestmannaeyjar
# Processing 31 of Set 4 : gander
# Processing 32 of Set 4 : orcopampa
# Processing 33 of Set 4 : grand-bourg
# Processing 34 of Set 4 : jackson
# Processing 35 of Set 4 : basavana bagevadi
# Processing 36 of Set 4 : korla
# Processing 37 of Set 4 : krasnopavlivka
# City not found. Skipping...
# Processing 38 of Set 4 : saint anthony
# Processing 39 of Set 4 : magaria
# Processing 40 of Set 4 : batagay-alyta
# Processing 41 of Set 4 : norwich
# Processing 42 of Set 4 : cabedelo
# Processing 43 of Set 4 : karratha
# Processing 44 of Set 4 : mount gambier
# Processing 45 of Set 4 : san alberto
# Processing 46 of Set 4 : te anau
# Processing 47 of Set 4 : sao joao da barra
# Processing 48 of Set 4 : saldanha
# Processing 49 of Set 4 : carroll
# Processing 50 of Set 4 : southbridge
# Processing 51 of Set 4 : atar
# Processing 52 of Set 4 : voitsberg
# Processing 53 of Set 4 : hambantota
# Processing 54 of Set 4 : pathein
# Processing 55 of Set 4 : chiang khong
# Processing 56 of Set 4 : pangnirtung
# Processing 0 of Set 5 : banda aceh
# Processing 1 of Set 5 : broken hill
# Processing 2 of Set 5 : belmopan
# Processing 3 of Set 5 : warri
# Processing 4 of Set 5 : maldonado
# City not found. Skipping...
# Processing 5 of Set 5 : manokwari
# Processing 6 of Set 5 : tera
# Processing 7 of Set 5 : guozhen
# Processing 8 of Set 5 : kutum
# Processing 9 of Set 5 : bintulu
# Processing 10 of Set 5 : berlevag
# Processing 11 of Set 5 : arcata
# Processing 12 of Set 5 : loukhi
# Processing 13 of Set 5 : ekhabi
# Processing 14 of Set 5 : nikolskoye
# Processing 15 of Set 5 : iqaluit
# Processing 16 of Set 5 : beloha
# Processing 17 of Set 5 : malaya serdoba
# Processing 18 of Set 5 : kholm
# Processing 19 of Set 5 : petauke
# Processing 20 of Set 5 : airai
# Processing 21 of Set 5 : faya
# Processing 22 of Set 5 : bethel
# Processing 23 of Set 5 : auki
# Processing 24 of Set 5 : kivertsi
# Processing 25 of Set 5 : luderitz
# Processing 26 of Set 5 : rio grande
# Processing 27 of Set 5 : nizhniy kuranakh
# Processing 28 of Set 5 : goderich
# Processing 29 of Set 5 : sabang
# Processing 30 of Set 5 : gambissara
# Processing 31 of Set 5 : kichmengskiy gorodok
# Processing 32 of Set 5 : dingle
# City not found. Skipping...
# Processing 33 of Set 5 : gambiran
# Processing 34 of Set 5 : lata
# Processing 35 of Set 5 : burnie
# Processing 36 of Set 5 : cidreira
# Processing 37 of Set 5 : bijie
# Processing 38 of Set 5 : aykhal
# Processing 39 of Set 5 : imbituba
# Processing 40 of Set 5 : sal rei
# Processing 41 of Set 5 : kharan
# Processing 42 of Set 5 : vangaindrano
# Processing 43 of Set 5 : pangai
# Processing 44 of Set 5 : san patricio
# Processing 45 of Set 5 : muravlenko
# Processing 46 of Set 5 : hofn
# Processing 47 of Set 5 : tortoli
# City not found. Skipping...
# Processing 48 of Set 5 : rokiskis
# Processing 49 of Set 5 : preston
# Processing 50 of Set 5 : vaitape
# Processing 51 of Set 5 : moron
# Processing 52 of Set 5 : rocha
# Processing 53 of Set 5 : kousseri
# City not found. Skipping...
# Processing 54 of Set 5 : usinsk
# Processing 55 of Set 5 : belyy yar
# Processing 56 of Set 5 : fougeres
# Processing 0 of Set 6 : pacific grove
# Processing 1 of Set 6 : lorengau
# Processing 2 of Set 6 : iskateley
# Processing 3 of Set 6 : biak
# Processing 4 of Set 6 : cockburn town
# Processing 5 of Set 6 : cherskiy
# Processing 6 of Set 6 : roseau
# Processing 7 of Set 6 : fare
# Processing 8 of Set 6 : port blair
# Processing 9 of Set 6 : hay river
# Processing 10 of Set 6 : trelew
# Processing 11 of Set 6 : krasnokamensk
# Processing 12 of Set 6 : grand gaube
# Processing 13 of Set 6 : port macquarie
# Processing 14 of Set 6 : kulhudhuffushi
# Processing 15 of Set 6 : pucallpa
# Processing 16 of Set 6 : ipubi
# Processing 17 of Set 6 : muros
# Processing 18 of Set 6 : reynosa
# Processing 19 of Set 6 : ambanja
# Processing 20 of Set 6 : bahar
# Processing 21 of Set 6 : funtua
# Processing 22 of Set 6 : seoul
# Processing 23 of Set 6 : prince albert
# Processing 24 of Set 6 : klaksvik
# Processing 25 of Set 6 : bambanglipuro
# Processing 26 of Set 6 : bismarck
# Processing 27 of Set 6 : camacha
# Processing 28 of Set 6 : teahupoo
# City not found. Skipping...
# Processing 29 of Set 6 : garden city
# Processing 30 of Set 6 : camabatela
# Processing 31 of Set 6 : la asuncion
# Processing 32 of Set 6 : muhos
# Processing 33 of Set 6 : meulaboh
# Processing 34 of Set 6 : dalby
# Processing 35 of Set 6 : middle island
# City not found. Skipping...
# City not found. Skipping...
# Processing 36 of Set 6 : pisco
# Processing 37 of Set 6 : shimoda
# Processing 38 of Set 6 : matadi
# Processing 39 of Set 6 : aquiraz
# Processing 40 of Set 6 : baruun-urt
# Processing 41 of Set 6 : makakilo city
# Processing 42 of Set 6 : maltahohe
# Processing 43 of Set 6 : taltal
# Processing 44 of Set 6 : lerwick
# Processing 45 of Set 6 : shasta lake
# City not found. Skipping...
# Processing 46 of Set 6 : la ronge
# Processing 47 of Set 6 : coihaique
# Processing 48 of Set 6 : flinders
# Processing 49 of Set 6 : hami
# Processing 50 of Set 6 : mersing
# Processing 51 of Set 6 : bonavista
# Processing 52 of Set 6 : mantua
# Processing 53 of Set 6 : dondukovskaya
# Processing 54 of Set 6 : katsuura
# Processing 55 of Set 6 : marsabit
# Processing 56 of Set 6 : huarmey
# Processing 0 of Set 7 : nobres
# City not found. Skipping...
# Processing 1 of Set 7 : hovd
# Processing 2 of Set 7 : akdagmadeni
# Processing 3 of Set 7 : sao jose da coroa grande
# City not found. Skipping...
# Processing 4 of Set 7 : norilsk
# Processing 5 of Set 7 : nichinan
# Processing 6 of Set 7 : deputatskiy
# Processing 7 of Set 7 : svetlopolyansk
# Processing 8 of Set 7 : chapleau
# Processing 9 of Set 7 : doka
# Processing 10 of Set 7 : yerbogachen
# Processing 11 of Set 7 : toamasina
# Processing 12 of Set 7 : mana
# Processing 13 of Set 7 : kovdor
# Processing 14 of Set 7 : wanning
# City not found. Skipping...
# Processing 15 of Set 7 : maniitsoq
# Processing 16 of Set 7 : narsaq
# Processing 17 of Set 7 : labuhan
# Processing 18 of Set 7 : saint-georges
# Processing 19 of Set 7 : whitianga
# Processing 20 of Set 7 : koutiala
# Processing 21 of Set 7 : san cristobal
# Processing 22 of Set 7 : kabo
# Processing 23 of Set 7 : lukovetskiy
# Processing 24 of Set 7 : kalmunai
# Processing 25 of Set 7 : beatrice
# Processing 26 of Set 7 : ingham
# Processing 27 of Set 7 : puerto ayacucho
# Processing 28 of Set 7 : snasa
# Processing 29 of Set 7 : solton
# Processing 30 of Set 7 : arboletes
# Processing 31 of Set 7 : ushtobe
# Processing 32 of Set 7 : yingcheng
# Processing 33 of Set 7 : solwezi
# Processing 34 of Set 7 : ascension
# Processing 35 of Set 7 : wilmington
# Processing 36 of Set 7 : kingman
# Processing 37 of Set 7 : aripuana
# Processing 38 of Set 7 : deer lake
# Processing 39 of Set 7 : fort nelson
# Processing 40 of Set 7 : andenes
# Processing 41 of Set 7 : erenhot
# Processing 42 of Set 7 : sakakah
# City not found. Skipping...
# Processing 43 of Set 7 : chumikan
# Processing 44 of Set 7 : palasa
# Processing 45 of Set 7 : axim
# Processing 46 of Set 7 : mabaruma
# Processing 47 of Set 7 : saint-paul
# Processing 48 of Set 7 : anchorage
# Processing 49 of Set 7 : kuruman
# Processing 50 of Set 7 : buchanan
# City not found. Skipping...
# Processing 51 of Set 7 : ugoofaaru
# Processing 52 of Set 7 : port-cartier
# City not found. Skipping...
# Processing 53 of Set 7 : ust-ilimsk
# Processing 54 of Set 7 : tucuman
# Processing 55 of Set 7 : college
# Processing 56 of Set 7 : onoda
# Processing 0 of Set 8 : abastumani
# Processing 1 of Set 8 : san policarpo
# Processing 2 of Set 8 : hualmay
# Processing 3 of Set 8 : bako
# Processing 4 of Set 8 : codrington
# Processing 5 of Set 8 : monteagudo
# City not found. Skipping...
# City not found. Skipping...
# Processing 6 of Set 8 : kaohsiung
# Processing 7 of Set 8 : presidencia roque saenz pena
# Processing 8 of Set 8 : virginia beach
# Processing 9 of Set 8 : waingapu
# Processing 10 of Set 8 : harper
# Processing 11 of Set 8 : mecca
# Processing 12 of Set 8 : snyder
# Processing 13 of Set 8 : vestmanna
# Processing 14 of Set 8 : buturlino
# Processing 15 of Set 8 : plettenberg bay
# Processing 16 of Set 8 : shubarkuduk
# Processing 17 of Set 8 : dickinson
# Processing 18 of Set 8 : ambilobe
# Processing 19 of Set 8 : cabo san lucas
# Processing 20 of Set 8 : sharkan
# Processing 21 of Set 8 : simi
# Processing 22 of Set 8 : anadyr
# Processing 23 of Set 8 : xinye
# Processing 24 of Set 8 : acapulco
# City not found. Skipping...
# Processing 25 of Set 8 : manggar
# Processing 26 of Set 8 : san quintin
# Processing 27 of Set 8 : northam
# Processing 28 of Set 8 : tabou
# Processing 29 of Set 8 : zhigansk
# Processing 30 of Set 8 : kirn
# Processing 31 of Set 8 : inverell
# Processing 32 of Set 8 : luis correia
# City not found. Skipping...
# Processing 33 of Set 8 : komsomolets
# Processing 34 of Set 8 : sakaiminato
# Processing 35 of Set 8 : kuala pilah
# Processing 36 of Set 8 : igarka
# Processing 37 of Set 8 : sosnovo-ozerskoye
# Processing 38 of Set 8 : ust-karsk
# Processing 39 of Set 8 : crossville
# Processing 40 of Set 8 : koslan
# Processing 41 of Set 8 : nizhnevartovsk
# Processing 42 of Set 8 : varhaug
# Processing 43 of Set 8 : guipavas
# City not found. Skipping...
# Processing 44 of Set 8 : puerto del rosario
# Processing 45 of Set 8 : golden
# Processing 46 of Set 8 : inhambane
# Processing 47 of Set 8 : gamboma
# Processing 48 of Set 8 : brownsville
# Processing 49 of Set 8 : talisayan
# Processing 50 of Set 8 : chaiyaphum
# Processing 51 of Set 8 : kichera
# Processing 52 of Set 8 : port pirie
# Processing 53 of Set 8 : khlevnoye
# Processing 54 of Set 8 : zhezkazgan
# Processing 55 of Set 8 : karimpur
# City not found. Skipping...
# Processing 56 of Set 8 : ixtapa
# Processing 0 of Set 9 : zeewolde
# Processing 1 of Set 9 : gornopravdinsk
# Processing 2 of Set 9 : kampene
# Processing 3 of Set 9 : bouafle
# Processing 4 of Set 9 : suihua
# Processing 5 of Set 9 : wuxue
# Processing 6 of Set 9 : quimperle
# Processing 7 of Set 9 : sorland
# Processing 8 of Set 9 : ola
# Processing 9 of Set 9 : porto belo
# Processing 10 of Set 9 : dvinskoy
# Processing 11 of Set 9 : coquimbo
# Processing 12 of Set 9 : beringovskiy
# Processing 13 of Set 9 : carutapera
# Processing 14 of Set 9 : isangel
# Processing 15 of Set 9 : kwakoa
# Processing 16 of Set 9 : asau
# Processing 17 of Set 9 : troitskoye
# Processing 18 of Set 9 : suifenhe
# Processing 19 of Set 9 : richards bay
# Processing 20 of Set 9 : koumac
# Processing 21 of Set 9 : vardo
# City not found. Skipping...
# Processing 22 of Set 9 : trunovskoye
# Processing 23 of Set 9 : kamenka
# Processing 24 of Set 9 : brokopondo
# Processing 25 of Set 9 : mount isa
# Processing 26 of Set 9 : vianopolis
# Processing 27 of Set 9 : parana
# Processing 28 of Set 9 : eichenzell
# Processing 29 of Set 9 : bilma
# Processing 30 of Set 9 : gao
# Processing 31 of Set 9 : bandarbeyla
# Processing 32 of Set 9 : emerald
# Processing 33 of Set 9 : williams lake
# Processing 34 of Set 9 : buala
# Processing 35 of Set 9 : nova borova
# Processing 36 of Set 9 : sitka
# Processing 37 of Set 9 : krasnogorskiy
# Processing 38 of Set 9 : bodden town
# Processing 39 of Set 9 : malindi
# Processing 40 of Set 9 : ust-maya
# Processing 41 of Set 9 : kizukuri
# Processing 42 of Set 9 : sao joao da ponte
# Processing 43 of Set 9 : khorixas
# Processing 44 of Set 9 : gilgit
# Processing 45 of Set 9 : genhe
# City not found. Skipping...
# Processing 46 of Set 9 : haines junction
# Processing 47 of Set 9 : tacuati
# Processing 48 of Set 9 : davila
# City not found. Skipping...
# Processing 49 of Set 9 : elbrus
# Processing 50 of Set 9 : ornskoldsvik
# Processing 51 of Set 9 : qui nhon
# Processing 52 of Set 9 : saint-augustin
# Processing 53 of Set 9 : omboue
# Processing 54 of Set 9 : alice springs
# Processing 55 of Set 9 : bom jesus
# Processing 56 of Set 9 : mandalgarh
# City not found. Skipping...
# Processing 0 of Set 10 : nizhnyaya salda
# Processing 1 of Set 10 : nanortalik
# Processing 2 of Set 10 : nantong
# Processing 3 of Set 10 : general pico
# Processing 4 of Set 10 : cambridge
# Processing 5 of Set 10 : mullingar
# Processing 6 of Set 10 : dubbo
# Processing 7 of Set 10 : komsomolskiy
# Processing 8 of Set 10 : chirongui
# Processing 9 of Set 10 : honiara
# City not found. Skipping...
# Processing 10 of Set 10 : bucerias
# Processing 11 of Set 10 : bhind
# Processing 12 of Set 10 : peniche
# Processing 13 of Set 10 : mezen
# Processing 14 of Set 10 : rawson
# Processing 15 of Set 10 : belle fourche
# Processing 16 of Set 10 : teya
# Processing 17 of Set 10 : port lincoln
# Processing 18 of Set 10 : kyenjojo
# Processing 19 of Set 10 : lewisville
# Processing 20 of Set 10 : ratnagiri
# City not found. Skipping...
# Processing 21 of Set 10 : cayambe
# Processing 22 of Set 10 : oistins
# Processing 23 of Set 10 : auchi
# Processing 24 of Set 10 : sagaing
# Processing 25 of Set 10 : velizh
# Processing 26 of Set 10 : chake chake
# Processing 27 of Set 10 : samarai
# Processing 28 of Set 10 : kamaishi
# Processing 29 of Set 10 : zatoka
# Processing 30 of Set 10 : jamame
# Processing 31 of Set 10 : dilla
# Processing 32 of Set 10 : hobyo
# Processing 33 of Set 10 : sohag
# Processing 34 of Set 10 : rabaul
# Processing 35 of Set 10 : sabha
# Processing 36 of Set 10 : luganville
# City not found. Skipping...
# Processing 37 of Set 10 : foxton
# Processing 38 of Set 10 : gwadar
# Processing 39 of Set 10 : okhotsk
# Processing 40 of Set 10 : raichur
# Processing 41 of Set 10 : nemuro
# Processing 42 of Set 10 : purpe
# Processing 43 of Set 10 : barcelos
# Processing 44 of Set 10 : uddevalla
# Processing 45 of Set 10 : maningrida
# Processing 46 of Set 10 : ouesso
# Processing 47 of Set 10 : duldurga
# Processing 48 of Set 10 : lufilufi
# City not found. Skipping...
# Processing 49 of Set 10 : thurso
# Processing 50 of Set 10 : sambava
# Processing 51 of Set 10 : sarakhs
# Processing 52 of Set 10 : katherine
# Processing 53 of Set 10 : hueytown
# Processing 54 of Set 10 : sibu
# Processing 55 of Set 10 : conde
# City not found. Skipping...
# City not found. Skipping...
# Processing 56 of Set 10 : lakki marwat
# Processing 0 of Set 11 : suntar
# Processing 1 of Set 11 : zeya
# Processing 2 of Set 11 : unity
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ## Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_gen.head()
# Out:
#                City Country    Lat     Lng Max Temp Cloudiness Humidity  \
# 0            atuona      pf   -9.8 -139.03    78.33          1       76
# 1  illoqqortoormiut      gl
# 2         grindavik      is  63.84  -22.43     46.4         90       87
# 3     mar del plata      ar    -38  -57.56    51.01         13       70
# 4         flin flon      ca  54.77 -101.86    37.83         60       76
#
#   Windspeed        Date
# 0     17.52  1600225372
# 1
# 2     14.99  1600225382
# 3      3.36  1600225224
# 4     16.46  1600225383

# %%
cities_gen.head(50)
# Out:
#                 City Country    Lat     Lng Max Temp Cloudiness Humidity  \
# 0             atuona      pf   -9.8 -139.03    78.33          1       76
# 1   illoqqortoormiut      gl
# 2          grindavik      is  63.84  -22.43     46.4         90       87
# 3      mar del plata      ar    -38  -57.56    51.01         13       70
# 4          flin flon      ca  54.77 -101.86    37.83         60       76
# 5            vilhena      br -12.74  -60.15    74.14          0       29
# 6            rikitea      pf -23.12 -134.97    74.07          0       71
# 7       punta arenas      cl -53.15  -70.92       32          0       85
# 8        bridlington      gb  54.08   -0.19       61         92      100
# 9         kaitangata      nz -46.28  169.85       52         90       69
# 10            tiarei      pf -17.53 -149.33     82.4         40       69
# 11       provideniya      ru  64.38  -173.3       50         90       81
# 12            palmer      us  42.16  -72.33    51.01         90       87
# 13            albany      au   42.6  -73.97    48.99          8       69
# 14            laguna      br  38.42 -121.42     82.4          1       32
# 15       meadow lake      ca   34.8 -106.54     73.4         40       25
# 16          thompson      ca  55.74  -97.86     37.4         75       86
# 17           mataura      pf -46.19  168.86    48.99        100       90
# 18           fortuna      us   40.6 -124.16       70          1       88
# 19          portland      au  45.52 -122.68       70         90       64
# 20             bluff      nz  -46.6  168.33    48.99         99       90
# 21             vaini      to  -21.2  -175.2     75.2         40       78
# 22           mareeba      au    -17  145.43       82         25       57
# 23        butaritari      ki   3.07  172.79    83.84         47       73
# 24         carnarvon      au -24.87  113.63     71.6          0       68
# 25       yellowknife      ca  62.46 -114.35     33.8         20       50
# 26         esperance      au -33.87   121.9     57.2         90       93
# 27            faanui      pf -16.48 -151.75    77.94          0       79
# 28           qaanaaq      gl  77.48  -69.36    19.26          0       77
# 29           zuwarah      ly  32.93   12.08    78.94          0       69
# 30       port alfred      za -33.59   26.89    56.95         41       87
# 31              raga      sd   8.46   25.68    68.18        100       94
# 32      saint george      bm   37.1 -113.58     91.4          1        9
# 33             kapaa      us  22.08 -159.32     84.2         20       62
# 34    port elizabeth      za -33.92   25.57     55.4         75       93
# 35            ulagan      ru  50.63   87.96    55.58        100       39
# 36   bambous virieux      mu -20.34   57.76    69.01         75       60
# 37       new norfolk      au -42.78  147.06     64.4         90       36
# 38            bozoum      cf   6.32   16.38    68.59         92       95
# 39         busselton      au -33.65  115.33    57.99         45       71
# 40            kodiak      us  57.79 -152.41    56.23         49       90
# 41       spilamberto      it  44.53   11.02       72          0       58
# 42         jacobabad      pk  28.28   68.44    90.07         87       50
# 43            dikson      ru  73.51   80.55    42.35        100       94
# 44            olinda      br  -8.01  -34.86       77         40       83
# 45       santa maria      cv -29.68  -53.81     53.6         90      100
# 46            bargal      so
# 47         taolanaro      mg
# 48            masuda      jp  34.67  131.85     78.8         75       69
# 49        lavrentiya      ru  65.58    -171    45.82         96       86
#
#    Windspeed        Date
# 0      17.52  1600225372
# 1
# 2      14.99  1600225382
# 3       3.36  1600225224
# 4      16.46  1600225383
# 5       2.48  1600225383
# 6        0.4  1600225383
# 7       8.05  1600225383
# 8       2.24  1600225383
# 9         17  1600225383
# 10     11.41  1600225384
# 11      6.71  1600225384
# 12      4.54  1600225384
# 13      2.59  1600225203
# 14      3.36  1600225384
# 15      9.17  1600225384
# 16     13.87  1600225385
# 17        21  1600225385
# 18      5.82  1600225385
# 19       3.2  1600225320
# 20        21  1600225385
# 21     11.41  1600225385
# 22      5.01  1600225385
# 23     16.98  1600225386
# 24     24.16  1600225386
# 25       4.7  1600225201
# 26     16.11  1600225386
# 27     15.57  1600225386
# 28      7.25  1600225386
# 29     13.06  1600225232
# 30      5.55  1600225387
# 31      4.03  1600225387
# 32     10.29  1600225327
# 33     10.29  1600225232
# 34      3.36  1600225387
# 35      1.61  1600225387
# 36      9.17  1600225388
# 37     21.92  1600225388
# 38      1.21  1600225388
# 39     11.99  1600225388
# 40      5.19  1600225388
# 41      1.99  1600225389
# 42      3.09  1600225206
# 43     16.22  1600225389
# 44     12.75  1600225389
# 45      3.36  1600225361
# 46
# 47
# 48      9.17  1600225409
# 49     13.62  1600225410

# %%
#cleaning data from empty rows
newcities_gen = cities_gen.replace('', np.nan)
cities_data = newcities_gen.dropna()
cities_data
# Out:
#               City Country    Lat     Lng  Max Temp  Cloudiness  Humidity  \
# 0           atuona      pf  -9.80 -139.03     78.33         1.0      76.0
# 2        grindavik      is  63.84  -22.43     46.40        90.0      87.0
# 3    mar del plata      ar -38.00  -57.56     51.01        13.0      70.0
# 4        flin flon      ca  54.77 -101.86     37.83        60.0      76.0
# 5          vilhena      br -12.74  -60.15     74.14         0.0      29.0
# ..             ...     ...    ...     ...       ...         ...       ...
# 608          conde      br  -7.26  -34.91     73.40        20.0      94.0
# 611   lakki marwat      pk  32.61   70.91     92.32         0.0      28.0
# 612         suntar      ru  62.14  117.63     58.50        78.0      59.0
# 613           zeya      ru  53.75  127.27     67.42       100.0      57.0
# 614          unity      ca  52.45 -109.17     44.60        44.0      75.0
#
#      Windspeed          Date
# 0        17.52  1.600225e+09
# 2        14.99  1.600225e+09
# 3         3.36  1.600225e+09
# 4        16.46  1.600225e+09
# 5         2.48  1.600225e+09
# ..         ...           ...
# 608       5.82  1.600226e+09
# 611       5.37  1.600226e+09
# 612       0.40  1.600226e+09
# 613       1.79  1.600226e+09
# 614       8.25  1.600226e+09
#
# [572 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_data.to_csv("output_data/weather_citydata.csv", index = False)
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.
count = cities_data[['Lat', 'Lng', 'Max Temp', 'Cloudiness', 'Humidity','Windspeed']].count()
mean = cities_data[['Lat', 'Lng', 'Max Temp', 'Cloudiness', 'Humidity','Windspeed']].mean()
std= cities_data[['Lat', 'Lng', 'Max Temp', 'Cloudiness', 'Humidity','Windspeed']].std()
mini= cities_data[['Lat', 'Lng', 'Max Temp', 'Cloudiness', 'Humidity','Windspeed']].min()
quartiles = cities_data[['Lat', 'Lng', 'Max Temp', 'Cloudiness', 'Humidity','Windspeed']].quantile([.25,.5,.75])
q1 = quartiles.loc[0.25]
q2 =quartiles.loc[0.50]
q3 =quartiles.loc[0.75]
maxi = cities_data[['Lat', 'Lng', 'Max Temp', 'Cloudiness', 'Humidity','Windspeed']].max()

city_weather_stat = pd.DataFrame({"Count":count,"mean":mean, "Std": std, "Min": min, '25%': q1, '50%': q2, '75%': q3, 'Max': maxi})
city_weather_stat = city_weather_stat.transpose()
city_weather_stat
# Out:
#               Lat         Lng    Max Temp  Cloudiness    Humidity   Windspeed
# Count  572.000000  572.000000  572.000000  572.000000  572.000000  572.000000
# mean    19.873007   18.559633   65.230262   55.377622   72.900350    7.770734
# Std     33.885207   90.477655   15.076691   38.868462   19.292627    5.450159
# Min    -54.800000 -175.200000   19.260000    0.000000    9.000000    0.400000
# 25%     -8.950000  -58.627500   53.582500   19.000000   62.000000    3.415000
# 50%     21.450000   23.300000   66.990000   69.000000   77.000000    6.550000
# 75%     50.680000   95.485000   77.372500   94.000000   88.000000   10.707500
# Max     78.220000  179.320000   97.920000  100.000000  100.000000   38.030000

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = cities_data['Lat']
y_values = cities_data['Max Temp']
plt.figure(figsize=(10,5))
plt.scatter(x_values, y_values, facecolors="darkslateblue", alpha=0.8, s=y_values)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Max Temperature', fontsize=14)
plt.title("City Latitude vs. Max Temperature (09/15/20)")
plt.savefig("output_data/City Latitude vs Max Temperature.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = cities_data['Lat']
y_values = cities_data['Humidity']
plt.figure(figsize=(10,5))
plt.scatter(x_values, y_values, facecolors="darkslateblue", alpha=0.8, s=y_values)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Humidity %', fontsize=14)
plt.title("City Latitude vs. Humidity (09/15/20)")
plt.savefig("output_data/City Latitude vs Humidity.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = cities_data['Lat']
y_values = cities_data['Cloudiness']
plt.figure(figsize=(10,5))
plt.scatter(x_values, y_values, facecolors="darkslateblue", alpha=0.8, s=y_values)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Cloudiness %', fontsize=14)
plt.title("City Latitude vs. Cloudiness (09/15/20)")
plt.savefig("output_data/City Latitude vs Cloudiness.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
